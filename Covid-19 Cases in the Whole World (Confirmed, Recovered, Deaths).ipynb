# %%
# !pip install folium
# !pip install plotly

# %%
# imports
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

import folium


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

import math
import random 
from datetime import timedelta

import warnings
warnings.filterwarnings('ignore')


#color pallette
cnf = '#393e46'
dth = '#ff2e63'
rec = '#21bf73'
act = '#fe9801'

# %%
import plotly as py
py.offline.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv('C:/Users/Dell/Desktop/Data Work/Covid-19-Preprocessed-Dataset/preprocessed/covid_19_data_cleaned.csv', parse_dates=['Date'])


country_daywise=pd.read_csv('C:/Users/Dell/Desktop/Data Work/Covid-19-Preprocessed-Dataset/preprocessed/country_daywise.csv', parse_dates=['Date'])
countrywise=pd.read_csv('C:/Users/Dell/Desktop/Data Work/Covid-19-Preprocessed-Dataset/preprocessed/countrywise.csv')
daywise=pd.read_csv('C:/Users/Dell/Desktop/Data Work/Covid-19-Preprocessed-Dataset/preprocessed/daywise.csv', parse_dates=['Date'])

# %%
df
# Out:
#             Date Province/State      Country        Lat       Long  Confirmed  \
# 0     2020-01-22            NaN  Afghanistan  33.000000  65.000000          0
# 1     2020-01-23            NaN  Afghanistan  33.000000  65.000000          0
# 2     2020-01-24            NaN  Afghanistan  33.000000  65.000000          0
# 3     2020-01-25            NaN  Afghanistan  33.000000  65.000000          0
# 4     2020-01-26            NaN  Afghanistan  33.000000  65.000000          0
# ...          ...            ...          ...        ...        ...        ...
# 36244 2020-05-25            NaN   Tajikistan  38.861034  71.276093          0
# 36245 2020-05-26            NaN   Tajikistan  38.861034  71.276093          0
# 36246 2020-05-27            NaN   Tajikistan  38.861034  71.276093          0
# 36247 2020-05-28            NaN   Tajikistan  38.861034  71.276093          0
# 36248 2020-05-29            NaN   Tajikistan  38.861034  71.276093          0
#
#        Recovered  Deaths  Active
# ...

# %%
df['Province/State']=df['Province/State'].fillna("")
df
# Out:
#             Date Province/State      Country        Lat       Long  Confirmed  \
# 0     2020-01-22                 Afghanistan  33.000000  65.000000          0
# 1     2020-01-23                 Afghanistan  33.000000  65.000000          0
# 2     2020-01-24                 Afghanistan  33.000000  65.000000          0
# 3     2020-01-25                 Afghanistan  33.000000  65.000000          0
# 4     2020-01-26                 Afghanistan  33.000000  65.000000          0
# ...          ...            ...          ...        ...        ...        ...
# 36244 2020-05-25                  Tajikistan  38.861034  71.276093          0
# 36245 2020-05-26                  Tajikistan  38.861034  71.276093          0
# 36246 2020-05-27                  Tajikistan  38.861034  71.276093          0
# 36247 2020-05-28                  Tajikistan  38.861034  71.276093          0
# 36248 2020-05-29                  Tajikistan  38.861034  71.276093          0
#
#        Recovered  Deaths  Active
# ...

# %%
country_daywise.tail(15)
# Out:
#             Date               Country  Confirmed  Deaths  Recovered   Active  \
# 24237 2020-05-09                Turkey     137115    3739      89480    43896
# 24238 2020-05-09                    US    1309550   78795     212534  1018221
# 24239 2020-05-09                Uganda        116       0         55       61
# 24240 2020-05-09               Ukraine      14710     376       2909    11425
# 24241 2020-05-09  United Arab Emirates      17417     185       4295    12937
# 24242 2020-05-09        United Kingdom     216525   31662       1001   183862
# 24243 2020-05-09               Uruguay        702      18        513      171
# 24244 2020-05-09            Uzbekistan       2349      10       1846      493
# 24245 2020-05-09             Venezuela        402      10        190      202
# 24246 2020-05-09               Vietnam        288       0        241       47
# 24247 2020-05-09    West Bank and Gaza        375       2        228      145
# ...

# %%
countrywise.head(6)
# Out:
#                Country  Confirmed  Deaths  Recovered  Active  New Cases  \
# 0          Afghanistan       4033     115        502    3416        255
# 1              Albania        856      31        627     198          6
# 2              Algeria       5558     494       2546    2518        189
# 3              Andorra        754      48        545     161          2
# 4               Angola         43       2         13      28          0
# 5  Antigua and Barbuda         25       3         19       3          0
#
#    Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 0                2.85                  12.45                   22.91
# 1                3.62                  73.25                    4.94
# 2                8.89                  45.81                   19.40
# 3                6.37                  72.28                    8.81
# 4                4.65                  30.23                   15.38
# ...

# %%
daywise.head(10)
# Out:
#         Date  Confirmed  Deaths  Recovered  Active  New Cases  \
# 0 2020-01-22        555      17         28     510          0
# 1 2020-01-23        654      18         30     606         99
# 2 2020-01-24        941      26         36     879        287
# 3 2020-01-25       1434      42         39    1353        493
# 4 2020-01-26       2118      56         52    2010        684
# 5 2020-01-27       2927      82         61    2784        809
# 6 2020-01-28       5578     131        107    5340       2651
# 7 2020-01-29       6166     133        126    5907        588
# 8 2020-01-30       8234     171        143    7920       2068
# 9 2020-01-31       9927     213        222    9492       1693
#
#    Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 0                3.06                   5.05                   60.71
# 1                2.75                   4.59                   60.00
# 2                2.76                   3.83                   72.22
# ...

# %%
Confirmed = df.groupby('Date').sum()['Confirmed'].reset_index()
Confirmed
# Out:
#           Date  Confirmed
# 0   2020-01-22        555
# 1   2020-01-23        654
# 2   2020-01-24        941
# 3   2020-01-25       1434
# 4   2020-01-26       2118
# ..         ...        ...
# 124 2020-05-25    5495061
# 125 2020-05-26    5589626
# 126 2020-05-27    5691790
# 127 2020-05-28    5808946
# 128 2020-05-29    5924275
#
# [129 rows x 2 columns]

# %%
Recovered = df.groupby('Date').sum()['Recovered'].reset_index()
Recovered
# Out:
#           Date  Recovered
# 0   2020-01-22         28
# 1   2020-01-23         30
# 2   2020-01-24         36
# 3   2020-01-25         39
# 4   2020-01-26         52
# ..         ...        ...
# 124 2020-05-25    2231738
# 125 2020-05-26    2286956
# 126 2020-05-27    2350088
# 127 2020-05-28    2415960
# 128 2020-05-29    2493535
#
# [129 rows x 2 columns]

# %%
Deaths = df.groupby('Date').sum()['Deaths'].reset_index()
Deaths
# Out:
#           Date  Deaths
# 0   2020-01-22      17
# 1   2020-01-23      18
# 2   2020-01-24      26
# 3   2020-01-25      42
# 4   2020-01-26      56
# ..         ...     ...
# 124 2020-05-25  346231
# 125 2020-05-26  350452
# 126 2020-05-27  355628
# 127 2020-05-28  360308
# 128 2020-05-29  364867
#
# [129 rows x 2 columns]

# %%
df['Province/State']=df['Province/State'].fillna("")
df
# Out:
#             Date Province/State      Country        Lat       Long  Confirmed  \
# 0     2020-01-22                 Afghanistan  33.000000  65.000000          0
# 1     2020-01-23                 Afghanistan  33.000000  65.000000          0
# 2     2020-01-24                 Afghanistan  33.000000  65.000000          0
# 3     2020-01-25                 Afghanistan  33.000000  65.000000          0
# 4     2020-01-26                 Afghanistan  33.000000  65.000000          0
# ...          ...            ...          ...        ...        ...        ...
# 36244 2020-05-25                  Tajikistan  38.861034  71.276093          0
# 36245 2020-05-26                  Tajikistan  38.861034  71.276093          0
# 36246 2020-05-27                  Tajikistan  38.861034  71.276093          0
# 36247 2020-05-28                  Tajikistan  38.861034  71.276093          0
# 36248 2020-05-29                  Tajikistan  38.861034  71.276093          0
#
#        Recovered  Deaths  Active
# ...

# %%
df.isnull().sum()
# Out:
# Date              0
# Province/State    0
# Country           0
# Lat               0
# Long              0
# Confirmed         0
# Recovered         0
# Deaths            0
# Active            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36249 entries, 0 to 36248
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            36249 non-null  datetime64[ns]
#  1   Province/State  36249 non-null  object
#  2   Country         36249 non-null  object
#  3   Lat             36249 non-null  float64
#  4   Long            36249 non-null  float64
#  5   Confirmed       36249 non-null  int64
#  6   Recovered       36249 non-null  int64
#  7   Deaths          36249 non-null  int64
#  8   Active          36249 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 2.5+ MB

# %%
df.query('Country == "US"').tail(8)
# Out:
#             Date Province/State Country      Lat     Long  Confirmed  \
# 29146 2020-05-22                     US  37.0902 -95.7129    1600937
# 29147 2020-05-23                     US  37.0902 -95.7129    1622612
# 29148 2020-05-24                     US  37.0902 -95.7129    1643246
# 29149 2020-05-25                     US  37.0902 -95.7129    1662302
# 29150 2020-05-26                     US  37.0902 -95.7129    1680913
# 29151 2020-05-27                     US  37.0902 -95.7129    1699176
# 29152 2020-05-28                     US  37.0902 -95.7129    1721753
# 29153 2020-05-29                     US  37.0902 -95.7129    1746019
#
#        Recovered  Deaths   Active
# 29146     350135   95978  1154824
# 29147     361239   97086  1164287
# 29148     366736   97719  1178791
# 29149     379157   98219  1184926
# 29150     384902   98912  1197099
# 29151     391508  100417  1207251
# 29152     399991  101616  1220146
# 29153     406446  102809  1236764

# %%
Confirmed.tail()
# Out:
#           Date  Confirmed
# 124 2020-05-25    5495061
# 125 2020-05-26    5589626
# 126 2020-05-27    5691790
# 127 2020-05-28    5808946
# 128 2020-05-29    5924275

# %%
Recovered.tail()
# Out:
#           Date  Recovered
# 124 2020-05-25    2231738
# 125 2020-05-26    2286956
# 126 2020-05-27    2350088
# 127 2020-05-28    2415960
# 128 2020-05-29    2493535

# %%
Deaths.tail()
# Out:
#           Date  Deaths
# 124 2020-05-25  346231
# 125 2020-05-26  350452
# 126 2020-05-27  355628
# 127 2020-05-28  360308
# 128 2020-05-29  364867

# %%
import matplotlib.pyplot as plt
fig = go.Figure()
fig.add_trace(go.Scatter(x = Confirmed['Date'], y=Confirmed['Confirmed'], name='Confirmed'))
fig.add_trace(go.Scatter(x = Recovered['Date'], y=Recovered['Recovered'], name='Recovered'))
fig.add_trace(go.Scatter(x = Deaths['Date'], y=Deaths['Deaths'], name='deaths'))
fig.update_layout(title = 'Covid-19 Cases in the Whole World', xaxis_tickfont_size = 14, yaxis = dict(title = 'Number of Covid-19 Cases'))
fig.show()
# Out:
# <div>
#
#
#             <div id="5902b1a6-e2c3-46f8-bcd6-a47f60c9d683" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5902b1a6-e2c3-46f8-bcd6-a47f60c9d683")) {
#                     Plotly.newPlot(
#                         '5902b1a6-e2c3-46f8-bcd6-a47f60c9d683',
# ...
